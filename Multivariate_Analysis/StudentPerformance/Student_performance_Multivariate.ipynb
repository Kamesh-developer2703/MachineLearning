# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
import pandas as pd
df = pd.read_csv('Student_Performance.csv')
df.head(3)
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0

# %% [markdown]
# # We have string value on ExtraCurricular Activities

# %%
df['Extracurricular Activities'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['Extracurricular Activities']=df['Extracurricular Activities'].map({"Yes":1,"No":0})
df['Extracurricular Activities'].head(3)
# Out:
# 0    1
# 1    0
# 2    1
# Name: Extracurricular Activities, dtype: int64

# %%
df
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0                 7               99                           1            9
# 1                 4               82                           0            4
# 2                 8               51                           1            7
# 3                 5               52                           1            5
# 4                 7               75                           0            8
# ...             ...              ...                         ...          ...
# 9995              1               49                           1            4
# 9996              7               64                           1            8
# 9997              6               83                           1            8
# 9998              9               97                           1            7
# 9999              7               74                           0            8
#
# ...

# %%
x=df.drop("Performance Index",axis=1)
y=df["Performance Index"]

# %%
x.shape
# Out:
# (10000, 5)

# %%
y.shape
# Out:
# (10000,)

# %%
5x.head(3)
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              7               99                           1            9
# 1              4               82                           0            4
# 2              8               51                           1            7
#
#    Sample Question Papers Practiced
# 0                                 1
# 1                                 2
# 2                                 2

# %%
y.head(3)
# Out:
# 0    91.0
# 1    65.0
# 2    45.0
# Name: Performance Index, dtype: float64

# %%
model = LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([2.85298205, 1.01843419, 0.61289758, 0.48055975, 0.19380214])

# %%
model.intercept_
# Out:
# np.float64(-34.0755880919139)

# %%
Hours_Studied=int(input("Enter The Hours Studied by Student : "))
Previous_Scores = int(input("Enter The Previous Scores of the Student :"))
Extracurricular_Activities = int(input("Enter The Extracurricular Activities of Student (Valid 1 or 0) :"))
if Extracurricular_Activities>1 or Extracurricular_Activities<0:
    print("Invalid Extracurricular Activities")
Sleep_Hours=int(input("Enter The Sleep Hours of Student:"))
Sample_Question_Papers_Practiced = int(input("Enter The Sample Question Papers Practiced of Student  :"))

# %%
x.head(2)
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              7               99                           1            9
# 1              4               82                           0            4
#
#    Sample Question Papers Practiced
# 0                                 1
# 1                                 2

# %%
my_input=pd.DataFrame([[Hours_Studied,Previous_Scores,Extracurricular_Activities,Sleep_Hours,Sample_Question_Papers_Practiced]],columns=["Hours Studied","Previous Scores","Extracurricular Activities","Sleep Hours","Sample Question Papers Practiced"])

# %%
my_input.shape
# Out:
# (1, 5)

# %%
my_input.columns
# Out:
# Index(['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
#        'Sleep Hours', 'Sample Question Papers Practiced'],
#       dtype='object')

# %%
model.predict(my_input)
# Out:
# array([62.41759223])
